# %%
import random
board = [' ' for x in range(10)]


def printBoard(board):
    print('   |   |   ')
    print(' ' + board[1] + ' | ' + board[2] + ' | ' + board[3])
    print('   |   |   ')
    print('------------')
    print('   |   |   ')
    print(' ' + board[4] + ' | ' + board[5] + ' | ' + board[6])
    print('   |   |   ')
    print('------------')
    print('   |   |   ')
    print(' ' + board[7] + ' | ' + board[8] + ' | ' + board[9])
    print('   |   |   ')
printBoard(board)



def IsWinner(b,l):
    return (b[1]== l and b[2]==l and b[3]==l) or (b[4]== l and b[5]==l and b[6]==l) or \
    (b[7]== l and b[8]==l and b[9]==l) or \
    (b[1]== l and b[4]==l and b[7]==l) or (b[3]== l and b[6]==l and b[9]==l) or \
    (b[2]== l and b[5]==l and b[8]==l) or \
    (b[1]== l and b[5]==l and b[9]==l) or (b[3]== l and b[5]==l and b[7]==l)

def spaceIsFree(pos):
    return board[pos]==' '

def insertLetter(letter,pos):
    board[pos]=letter

def playerMove(symbol):
    run = True
    while run:
        move = input("please select a position to enter the {sym} between 1 to 9 : ".format(sym=symbol))
        try:
            move = int(move)
            if move > 0 and move < 10:
                if spaceIsFree(move):
                    run = False
                    insertLetter(symbol , move)
                else:
                    print('Sorry, this space is occupied')
            else:
                print('please type a number between 1 and 9 ')

        except:
            print('Please type a number')
def gameplay():
    for i in range(9):

        if(i%2==0):
            print("player 1's turn ")
            symbol='X'
            playerMove(symbol)
            printBoard(board)
            if IsWinner(board,'X'):
                print("player 1 won")
                break
        else:
            print("player 2's turn")
            symbol='O'
            playerMove(symbol)
            printBoard(board)
            if IsWinner(board,'O'):
                print("player 2 won")
                break
    else :
      print("Match Draw")
gameplay()

# %%
import random

# Initialize the game board
board = [' ' for _ in range(10)]

def printBoard(board):
    print('   |   |   ')
    print(' ' + board[1] + ' | ' + board[2] + ' | ' + board[3])
    print('   |   |   ')
    print('------------')
    print('   |   |   ')
    print(' ' + board[4] + ' | ' + board[5] + ' | ' + board[6])
    print('   |   |   ')
    print('------------')
    print('   |   |   ')
    print(' ' + board[7] + ' | ' + board[8] + ' | ' + board[9])
    print('   |   |   ')

def isWinner(b, l):
    return (
        (b[1] == l and b[2] == l and b[3] == l) or
        (b[4] == l and b[5] == l and b[6] == l) or
        (b[7] == l and b[8] == l and b[9] == l) or
        (b[1] == l and b[4] == l and b[7] == l) or
        (b[2] == l and b[5] == l and b[8] == l) or
        (b[3] == l and b[6] == l and b[9] == l) or
        (b[1] == l and b[5] == l and b[9] == l) or
        (b[3] == l and b[5] == l and b[7] == l)
    )

def spaceIsFree(pos):
    return board[pos] == ' '

def insertLetter(letter, pos):
    board[pos] = letter

def playerMove(symbol):
    run = True
    while run:
        move = input(f"Please select a position to enter the {symbol} (1-9): ")
        try:
            move = int(move)
            if 1 <= move <= 9:
                if spaceIsFree(move):
                    run = False
                    insertLetter(symbol, move)
                else:
                    print("Sorry, this space is occupied.")
            else:
                print("Please type a number between 1 and 9.")
        except ValueError:
            print("Please type a valid number.")

def aiMove():
    possibleMoves = [pos for pos, letter in enumerate(board) if letter == ' ' and pos != 0]
    move = 0

    for let in ['O', 'X']:
        for pos in possibleMoves:
            boardCopy = board[:]
            boardCopy[pos] = let
            if isWinner(boardCopy, let):
                move = pos
                return move

    if 5 in possibleMoves:
        return 5


    corners = [pos for pos in possibleMoves if pos in [1, 3, 7, 9]]
    if corners:
        return random.choice(corners)


    sides = [pos for pos in possibleMoves if pos in [2, 4, 6, 8]]
    if sides:
        return random.choice(sides)

    return move

def gameplay():
    print("Welcome to Human vs AI Tic-Tac-Toe!")
    printBoard(board)

    for i in range(9):
        if i % 2 == 0:
            print("Player's turn:")
            playerMove('X')
        else:
            print("AI's turn:")
            move = aiMove()
            if move != 0:
                insertLetter('O', move)
                print(f"AI chose position {move}.")
            else:
                print("No moves left for AI.")

        printBoard(board)

        if isWinner(board, 'X'):
            print("Player wins!")
            break
        elif isWinner(board, 'O'):
            print("AI wins!")
            break
    else:
        print("It's a draw!")

gameplay()
